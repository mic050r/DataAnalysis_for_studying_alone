# %% [markdown]
# <a href="https://colab.research.google.com/github/mic050r/DataAnalysis_for_studying_alone/blob/main/LibraryDataCheck_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2023년 11월).csv', encoding='EUC-KR', low_memory=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#    번호                   도서명                  저자       출판사  발행년도  \
# 0   1              그래봤자 개구리           장현정 쓰고 그림       키다리  2023
# 1   2            고양이 해결사 깜냥      홍민정 지음 ;김재희 그림        창비  2023
# 2   3                 퓨처 셀프  벤저민 하디 지음 ; 최은아 옮김     상상스퀘어  2023
# 3   4  투자 트렌드를 알면 100억이 보인다          김피비.곽상빈 지음  바이포엠스튜디오  2023
# 4   5        푸틴을 죽이는 완벽한 방법           김진명 (지은이)      이타북스  2023
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791157856374      NaN    7  NaN  813.8     1     0  2023-11-27
# 1  9788936448523      NaN    7    6  813.8     1     0  2023-11-27
# 2  9791192389325      NaN  NaN  NaN    NaN     1     0  2023-11-27
# 3  9791192579740      NaN  NaN  NaN    NaN     1     0  2023-11-27
# 4  9791167763983      NaN  NaN  NaN    NaN     1     0  2023-11-27
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv('ns_202311.csv')

# %%
with open('ns_202311.csv') as f:
  for i in range(3):
    print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,그래봤자 개구리,장현정 쓰고 그림,키다리,2023,9791157856374,,7,,813.8,1,0,2023-11-27,
# 1,2,고양이 해결사 깜냥,홍민정 지음 ;김재희 그림,창비,2023,9788936448523,,7,6,813.8,1,0,2023-11-27,

# %%
ns_df = pd.read_csv('ns_202311.csv', low_memory=False)
ns_df.head()
# Out:
#    Unnamed: 0  번호                   도서명                  저자       출판사  발행년도  \
# 0           0   1              그래봤자 개구리           장현정 쓰고 그림       키다리  2023
# 1           1   2            고양이 해결사 깜냥      홍민정 지음 ;김재희 그림        창비  2023
# 2           2   3                 퓨처 셀프  벤저민 하디 지음 ; 최은아 옮김     상상스퀘어  2023
# 3           3   4  투자 트렌드를 알면 100억이 보인다          김피비.곽상빈 지음  바이포엠스튜디오  2023
# 4           4   5        푸틴을 죽이는 완벽한 방법           김진명 (지은이)      이타북스  2023
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791157856374      NaN    7  NaN  813.8     1     0  2023-11-27
# 1  9788936448523      NaN    7    6  813.8     1     0  2023-11-27
# 2  9791192389325      NaN  NaN  NaN    NaN     1     0  2023-11-27
# 3  9791192579740      NaN  NaN  NaN    NaN     1     0  2023-11-27
# 4  9791167763983      NaN  NaN  NaN    NaN     1     0  2023-11-27
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
ns_df = pd.read_csv('ns_202311.csv', index_col = 0, low_memory=False)
ns_df.head()
# Out:
#    번호                   도서명                  저자       출판사  발행년도  \
# 0   1              그래봤자 개구리           장현정 쓰고 그림       키다리  2023
# 1   2            고양이 해결사 깜냥      홍민정 지음 ;김재희 그림        창비  2023
# 2   3                 퓨처 셀프  벤저민 하디 지음 ; 최은아 옮김     상상스퀘어  2023
# 3   4  투자 트렌드를 알면 100억이 보인다          김피비.곽상빈 지음  바이포엠스튜디오  2023
# 4   5        푸틴을 죽이는 완벽한 방법           김진명 (지은이)      이타북스  2023
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791157856374      NaN    7  NaN  813.8     1     0  2023-11-27
# 1  9788936448523      NaN    7    6  813.8     1     0  2023-11-27
# 2  9791192389325      NaN  NaN  NaN    NaN     1     0  2023-11-27
# 3  9791192579740      NaN  NaN  NaN    NaN     1     0  2023-11-27
# 4  9791167763983      NaN  NaN  NaN    NaN     1     0  2023-11-27
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv('ns_202311.csv', index=False)
